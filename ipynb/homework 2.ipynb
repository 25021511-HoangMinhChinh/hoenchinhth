# %%
#bai1
a=int(input('enter length'))
b=int(input('enter width'))
area=a*b
perimeter=(a+b)*2
print('area:',area,'\nperimeter:',perimeter)
# Out:
# area: 30
# perimeter: 22

# %%
#bai3
a,b,c= map(int,input("enter numbers:").split(","))
if a+b>c and a+c>b and b+c>a:
    print("a,b,c is the edges of the triangle")
if a==b!=c or a==c!=b or c==b!=a:
    print ("a,b,c is the edge of isosceles triangle")
if a**2+b**2==c**2 or a**2+c**2==b**2 or b**2+c**2==a**2:
    print ('a,b,c is the edge of right triangle')
if a==b==c :
    print ('a,b,c is the edge of isosceles triangle')
# Out:
# a,b,c is the edges of the triangle

# %%
a,b,c=map(int,input("enter numbers:").split(','))
if a!=0:
 
 b**2:
# Out:
#   Cell In[12], line 4
#     if b^2:
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2
