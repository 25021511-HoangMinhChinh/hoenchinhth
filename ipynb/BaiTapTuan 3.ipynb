# %%
n = int(input("Enter an integer n: "))
print("Double of n is:", 2 * n)
# Out:
# Double of n is: 8

# %%
a = float(input("Enter width a: "))
b = float(input("Enter length b: "))

pi = 3.14
r = a / 2          
remaining_area = a * b - pi * r ** 2

print(f"The remaining area for planting trees is: {remaining_area:.2f}")
# Out:
# The remaining area for planting trees is: 20.38

# %%
c = input("Enter a character: ")

if c.isupper():      
    print("The corresponding lowercase letter is:", c.lower())
elif c.islower():      
    print("The corresponding uppercase letter is:", c.upper())
else:
    print("The character is not a letter.")
# Out:
# The corresponding uppercase letter is: A

# %%
c=input("Enter a character: ")
if c.isupper():
    print("Character is in uppercase:", c)
else:
    print("Character is in lowercase:", ord(c))
# Out:
# Character is in lowercase: 97

# %%
a = input('enter character:' )
ord_a = ord(a)
ord_b = ord(a) + 1
char_a=chr(ord_a)
char_b=chr(ord_b)
print("character:", char_a,"\nnext character:", char_b)
# Out:
# character: f
# next character: g

# %%
a,b,c = map(float, input("Enter three sides of the triangle separated by spaces: ").split())
if a+b>c and b+c>a and a+c>b:
 print ( "the edge of triangle : a, b, c" )
else:
 print ( "not the edge of triangle : a, b, c" )
# Out:
# the edge of triangle : a, b, c

# %%
name=input("ten chu ho")
chi_so_thang_truoc= int(input("nhap cs_trc:"))
chi_so_thang_nay  = int (input("chi so thang nay :"))

tien=0
con_lai= kwh

#bac 1
bac= min(con_lai,50)
tien += bac *1984
con_lai-= bac

#bac 2
if con_lai >0:
    bac=min(con_lai,100)
    tien += bac *2050
    con_lai -= bac

#bac 3
if con_lai>0:
    bac=min(con_lai,200)
    tien += bac*2380
    con_lai -=bac

#bac 4
if con_lai>0:
   bac=min(con_lai,300)
   tien += bac*2998
   con_lai -=bac

#bac5
if con_lai>0:
   bac=min(con_lai,400)
   tien += bac*3350
   con_lai -=bac

#bac6
if con_lai>0:
   tien+= con_lai*3640

   tong_tien= int(round(tien*108))

print("Ho va ten:",name)
print("Tien phai tra la:",tong_tien)
# Out:
# Ho va ten: Mike Hawk
# Tien phai tra la: 918054

# %%
n=int(input('enter intergral'))
if n%2!=0:
 print('odd')
else:
 print ('even')
# Out:
# odd

# %%
n=int(input(''))
if n%2!=0 and n%5==0:
    print('so tan cung co 5')
else:
    print('so tan cung khong co 5')
# Out:
# so tan cung khong co 5

# %%
a=int(input('nam sinh'))
if 2025-a>=18:
    print('du tuoi di bau cu')
# Out:
# du tuoi di bau cu

# %%
ch=input('nhap 1 ki tu')
if '0'<=ch<='9':
    print('ky tu la so')
elif ('A'<= ch <='Z') or ('a'<=ch <= "z"):
    print('ky tu la chu')
else:
    print('ky tu khong la so cung khong la chu')
# Out:
# ky tu khong la so cung khong la chu

# %%
a=int(input('enter a number'))
if (a%400 ==0) or (a%4==0 and a%100!=0):
    print('day la nam nhuan')
else:
    print('khong phai nam nhuan')
