# %%
print ('Hello World')
# Out:
# Hello World

# %%
name = input("Hoàng Minh Chính")
print("Hello, " + name)
# Out:
# Hello, minh chinh

# %%
a = 10
b = 3

print(a + b)
print(a - b)
print(a * b)
print(a // b)
print(a % b)
print(f"{a / b:.2f}")
# Out:
# 13
# 7
# 30
# 3
# 1
# 3.33

# %%
a1=7
b1=8
c1=9
a2=6
b2=5
a3=4
TB=((a1+b1+c1)+(a2+b2)*2+a3*3)/10
print(f"Điểm trung bình là: {TB:.1f} ")
# Out:
# Điểm trung bình là: 5.8

# %%
a=2
b=3
print(a**b)
# Out:
# 8

# %%
a=b
