# %%
x=10
if x %2 ==0:
    print('x is even')
else:
    print('x is odd')
# Out:
# x is even

# %%
a=1
if a==0:
   b=a+1
else:
   b=a-5
print(b)
# Out:
# -4

# %%
score = int(input("Enter your score: "))
if score >= 90:
    print( "Excellent!")
elif score >= 70:
    print( "Good job!")
elif score >= 50:
    print('Passed!')
else: 
    print ("u filthy monky, ya such a fuking digrace that u r wasting your parents money")
# Out:
# u filthy monky, ya such a fuking digrace that u r wasting your parents money

# %%
x=0
if x==0:
    print('x is zero')
    if x==0:
        print('still no hoes')
    if x==0:
        print('i am zero')
# Out:
# x is zero
# still no hoes
# i am zero

# %%
raining=True
freezing=True
if not raining and freezing:
    print('wear warm coat')
elif not raining and not freezing:
    print ('wear sweater')
elif raining and freezing:
    print ('waterproof coat')
else:
    print ('take an umbrella')
# Out:
# waterproof coat

# %%
print ('before if')
if x_score > y_score:
    print ('inside if')
    winner= 'x'
    print ('winner ='+winner)
else:
    print ('inside else')
    winner= 'y'
    print ('winner ='+winner)
print ('after if')
# Out:
# before if
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 print ('before if')
# ----> 2 if x_score > y_score:
#       3     print ('inside if')
#       4     winner= 'x'
#
# NameError: name 'x_score' is not defined

# %%
raining = True
freezing = False
if raining :
    if freezing:
        print('wear waterproof coat')
    else:
        print('bring an umbrella')
else:
    if freezing:
        print('wear warm coat')
    else:
        print('wear sweater')
# Out:
# bring an umbrella

# %%
def move_forward():
    print("Moving forward")
    def turn_left():
     print("Turning left")

    turn_left()
move_forward()
# Out:
# Moving forward
# Turning left

# %%
raining = bool(input("Is it raining? (True/False): "))
if raining:
    print("Take an umbrella.")
else:
    print("No umbrella needed.")
# Out:
# Take an umbrella.

# %%
def what_to_wear(raining, freezing):
 if raining :
    if freezing:
        print('wear waterproof coat')
    else:
        print('bring an umbrella')
 else:
    if freezing:
        print('wear warm coat')
    else:
        print('wear sweater')

today_drip= what_to_wear(True, False)
sunny_drip= what_to_wear(False, False)
# Out:
# bring an umbrella
# wear sweater
